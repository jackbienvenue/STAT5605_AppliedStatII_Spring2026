# %% [markdown]
# # Connecticut All Injury Crashes (Jan 2015 - Jan 2026) Hotspot Map

# %%
# Package Import
import pandas as pd
import geopandas as gpd

# Data Upload

## CT Crashes

## CT Shapefile
ct_outline_gdf = gpd.read_file("../../data/ct_shapefile/Connecticut_Poly.shp")

## CT Towns Shapefile
ct_towns_gdf = gpd.read_file('../data/tl_2020_09_all/tl_2020_09_cousub20.shp')

# Check Temporal Extent of Data

## Check for Proper Coordinates:

# %% [markdown]
# ## Mapping Injury Crash Hotspots

# %%
# Mapping Hotspots

# %% [markdown]
# ## Mapping Town-by-Town Frequency

# %% [markdown]
# ## Mapping Town-by-Town Frequency, Population Normalized

# %% [markdown]
# ## Mapping Town-by-Town Injury Crash Frequency, Miles of Primary/Secondary Roads, Population Normalized
