# %% [markdown]
# # Data Cleaning and Preparation for STAT5605 Project

# %%
# Data Upload and Package Install

## Package Install
import pandas as pd
import geopandas as gpd
import numpy as np 
from typing import Iterable, Union

## Data Upload
### Roads Dataset
roads_gdf = gpd.read_file('../data/Connecticut_Road/Road.shp')
### CT Towns Dataset
ct_towns_gdf = gpd.read_file('../data/tl_2020_09_all/tl_2020_09_cousub20.shp')
### DP03: Selected Economic Characteristics (from ACS Census 2023)
DP03_df = pd.read_csv('../data/ACS_Selected_Economic_Characteristics_CT_2023/ACSDP5Y2023.DP03-Data.csv')
### DP05: Demographic and Housing Estimates (from ACS Census 2023)
DP05_df = pd.read_csv('../data/ACS_Demographic_and_Housing_Estimates_CT_2023/ACSDP5Y2023.DP05-Data.csv')

# %%
print(DP03_df.head())
# Out:
#                 GEO_ID                                               NAME  \
# 0            Geography                               Geographic Area Name
# 1  0600000US0911001080  Andover town, Capitol Planning Region, Connect...
# 2  0600000US0911002060    Avon town, Capitol Planning Region, Connecticut
# 3  0600000US0911004300  Berlin town, Capitol Planning Region, Connecticut
# 4  0600000US0911005910  Bloomfield town, Capitol Planning Region, Conn...
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                               2811
# 2                                              15105
# 3                                              16813
# 4                                              18788
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                 75
# 2                                                320
# 3                                                405
# 4                                                379
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                               1805
# 2                                               9844
# 3                                              11254
# 4                                              11569
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                148
# 2                                                522
# 3                                                601
# 4                                                537
#
#                                           DP03_0003E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                               1805
# 2                                               9830
# 3                                              11254
# 4                                              11523
#
#                                           DP03_0003M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                148
# 2                                                516
# 3                                                601
# 4                                                545
#
#                                           DP03_0004E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                               1796
# 2                                               9386
# 3                                              11071
# 4                                              11083
#
#                                           DP03_0004M  ...  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...  ...
# 1                                                149  ...
# 2                                                515  ...
# 3                                                611  ...
# 4                                                525  ...
#
#                                          DP03_0133PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                1.0
# 2                                                1.7
# 3                                                1.4
# 4                                                2.0
#
#                                          DP03_0134PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                0.9
# 2                                                4.7
# 3                                                3.6
# 4                                                7.7
#
#                                          DP03_0134PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                1.1
# 2                                                2.6
# 3                                                1.6
# 4                                                2.2
#
#                                          DP03_0135PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                1.5
# 2                                                4.8
# 3                                                5.7
# 4                                                5.0
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                2.2
# 2                                                2.9
# 3                                                3.0
# 4                                                2.5
#
#                                          DP03_0136PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                0.0
# 2                                                3.4
# 3                                                3.1
# 4                                                4.6
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                1.5
# 2                                                3.1
# 3                                                1.7
# 4                                                2.3
#
#                                          DP03_0137PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                9.7
# 2                                               12.4
# 3                                               12.6
# 4                                               16.8
#
#                                          DP03_0137PM Unnamed: 550
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...          NaN
# 1                                                8.7          NaN
# 2                                                5.9          NaN
# 3                                                5.4          NaN
# 4                                                4.4          NaN
#
# [5 rows x 551 columns]

# %% [markdown]
# ### Exploration of Data (Mapping Shapefiles)

# %%
# Mapping Shapefiles

## Mapping roads

ct_towns_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6673f60e88badaa2e79d1fa627a48719 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6673f60e88badaa2e79d1fa627a48719&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6673f60e88badaa2e79d1fa627a48719 = L.map(
#                 &quot;map_6673f60e88badaa2e79d1fa627a48719&quot;,
#                 {
#                     center: [41.50072679122968, -72.75750698214085],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_6673f60e88badaa2e79d1fa627a48719);
#
#
#
#
#
#             var tile_layer_01130538bff413ccfcdc9466e8a50c7f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01130538bff413ccfcdc9466e8a50c7f.addTo(map_6673f60e88badaa2e79d1fa627a48719);
#
#
#             map_6673f60e88badaa2e79d1fa627a48719.fitBounds(
#                 [[40.950942682557006, -73.7277749967754], [42.050510899902356, -71.7872389675063]],
#                 {}
#             );
#
#
#         function geo_json_884250719efb1ddf2c57d553752c64e7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_884250719efb1ddf2c57d553752c64e7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_884250719efb1ddf2c57d553752c64e7_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_884250719efb1ddf2c57d553752c64e7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_884250719efb1ddf2c57d553752c64e7_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_884250719efb1ddf2c57d553752c64e7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_884250719efb1ddf2c57d553752c64e7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_884250719efb1ddf2c57d553752c64e7 = L.geoJson(null, {
#                 onEachFeature: geo_json_884250719efb1ddf2c57d553752c64e7_onEachFeature,
#
#                 style: geo_json_884250719efb1ddf2c57d553752c64e7_styler,
#                 pointToLayer: geo_json_884250719efb1ddf2c57d553752c64e7_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_884250719efb1ddf2c57d553752c64e7_add (data) {
#             geo_json_884250719efb1ddf2c57d553752c64e7
#                 .addData(data);
#         }
#             geo_json_884250719efb1ddf2c57d553752c64e7_add({&quot;bbox&quot;: [-73.7277749967754, 40.950942682557006, -71.7872389675063, 42.050510899902356], &quot;features&quot;: [{&quot;bbox&quot;: [-72.96936439906146, 41.447956755176776, -72.8462964266601, 41.563811723455615], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-72.96922039914145, 41.53045372475907], [-72.96879039938118, 41.53111672474597], [-72.96864739946086, 41.53133772474162], [-72.9686303994637, 41.53133172474148], [-72

# %% [markdown]
# ## Merge of ACS Census Data into CT towns map

# %%
## Managing Merge of ACS Census Data into CT towns map

### Function: Merging csv into gdf 
def merge_csv_into_gdf(
    gdf: gpd.GeoDataFrame,
    csv_or_df: Union[str, pd.DataFrame],
    gdf_key: str = "GEOID10",
    csv_geo_col: str = "Geography",
    keep_columns: Iterable[str] = (), ## COLUMNS TO KEEP SPECIFICATION
    join_type: str = "left",
    geoid_regex: str = r"US(\d+)",
) -> gpd.GeoDataFrame:
    
    """
    Merge a CSV (or DataFrame) into a GeoDataFrame using a GEOID embedded
    in a 'Geography' column.
    
    Requires pandas, geopandas, and typing:
    'from typing import Iterable, Union'

    Parameters
    ----------
    gdf : GeoDataFrame
        Target GeoDataFrame (e.g. CT towns)
    csv_or_df : str or DataFrame
        Path to CSV file or already-loaded DataFrame
    gdf_key : str
        GEOID column in the GeoDataFrame
    csv_geo_col : str
        Column containing the GEOID string (e.g. 'US09001')
    keep_columns : iterable of str
        Columns to keep from the CSV (excluding GEOID)
    join_type : str
        pandas merge type ('left', 'right', 'inner', 'outer')
    geoid_regex : str
        Regex used to extract the numeric GEOID

    Returns
    -------
    GeoDataFrame
    """

    # Load CSV if data is not already imported as dataframe
    if isinstance(csv_or_df, str):
        df = pd.read_csv(csv_or_df)
    else:
        df = csv_or_df.copy()

    # Extract GEOID from dataframe
    df["_merge_geoid"] = (
        df[csv_geo_col]
        .astype(str)
        .str.extract(geoid_regex, expand=False)
    )

    # Ensure string type + zero padding (important for census GEOIDs)
    gdf[gdf_key] = gdf[gdf_key].astype(str)
    df["_merge_geoid"] = df["_merge_geoid"].astype(str)

    # Subset to only needed columns
    cols_to_use = ["_merge_geoid", *keep_columns]
    df = df[cols_to_use]

    # Merge
    merged = gdf.merge(
        df,
        how=join_type,
        left_on=gdf_key,
        right_on="_merge_geoid"
    )

    # Clean up
    merged = merged.drop(columns="_merge_geoid")

    return merged



## Perform merge for census data into CT towns

### Rename GeoID column for function
DP03_df = DP03_df.rename({'GEO_ID': '_merge_geoid'})
DP05_df = DP03_df.rename({'GEO_ID': '_merge_geoid'})

### Execute merging of csvs into dataframe
for csv, cols in [
    ("DP03_df", ["Population"]),
    ("DP05_df", ["MedianIncome"]),
]:
    ct_towns_gdf = merge_csv_into_gdf(
        ct_towns_gdf,
        csv,
        keep_columns=cols
    )

# %% [markdown]
# #### Data Cleanup (Removing excess information, false towns)

# %%
##

# %% [markdown]
# ## Calculation of Road Lengths in Towns

# %%
# Calculate Road Lengths in Town

'''
Here, we want to calculate the length of primary and secondary roads
'''

##

# %% [markdown]
# ## Merge Road Data into CT Towns Dataset

# %%
##
