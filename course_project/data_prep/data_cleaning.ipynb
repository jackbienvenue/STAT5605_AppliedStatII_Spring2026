# %% [markdown]
# # Data Cleaning and Preparation for STAT5605 Project

# %%
# Data Upload and Package Install

## Package Install
import pandas as pd
import geopandas as gpd
import numpy as np 
from typing import Iterable, Union

## Data Upload
### Roads Dataset
roads_gdf = gpd.read_file('../data/Connecticut_Road/Road.shp')
### CT Towns Dataset
ct_towns_gdf = gpd.read_file('../data/tl_2020_09_all/tl_2020_09_cousub20.shp')
### DP03: Selected Economic Characteristics (from ACS Census 2023)
DP03_df = pd.read_csv(
    '../data/ACS_Selected_Economic_Characteristics_CT_2023/ACSDP5Y2023.DP03-Data.csv',
    skiprows=[1]  
)
### DP05: Demographic and Housing Estimates (from ACS Census 2023)

DP05_df = pd.read_csv(
    '../data/ACS_Demographic_and_Housing_Estimates_CT_2023/ACSDP5Y2023.DP05-Data.csv',
    skiprows=[1]
)
### Crash Data

# %% [markdown]
# ### Exploration of Data (Mapping Shapefiles)

# %%
# Mapping Shapefiles
ct_towns_gdf.head()
## Mapping roads

#ct_towns_gdf.explore()
# Out:
#   STATEFP20 COUNTYFP20 COUSUBFP20 COUSUBNS20     GEOID20      NAME20  \
# 0        09        009      14160   00213406  0900914160    Cheshire
# 1        09        009      19550   00213418  0900919550       Derby
# 2        09        009      22910   00213425  0900922910  East Haven
# 3        09        003      12270   00213404  0900312270      Canton
# 4        09        009      67610   00213502  0900967610     Seymour
#
#         NAMELSAD20 LSAD20 CLASSFP20 MTFCC20 CNECTAFP20 NECTAFP20 NCTADVFP20  \
# 0    Cheshire town     43        T1   G4040        720     75700       None
# 1       Derby town     43        T5   G4040        720     71950       None
# 2  East Haven town     43        T1   G4040        720     75700       None
# 3      Canton town     43        T1   G4040        790     73450       None
# 4     Seymour town     43        T1   G4040        720     71950       None
#
#   FUNCSTAT20   ALAND20  AWATER20   INTPTLAT20    INTPTLON20  \
# 0          A  85035915   1254329  +41.5118273  -072.9036174
# 1          C  13094124    906368  +41.3261239  -073.0825739
# 2          A  31847384   3115993  +41.2934528  -072.8589937
# 3          A  63676508   1137667  +41.8587259  -072.9108619
# 4          A  37600679   1190094  +41.3854655  -073.0836408
#
#                                             geometry
# 0  POLYGON ((-72.96922 41.53045, -72.96879 41.531...
# 1  POLYGON ((-73.12456 41.34534, -73.12455 41.345...
# 2  POLYGON ((-72.90396 41.24089, -72.90271 41.242...
# 3  POLYGON ((-72.95384 41.84858, -72.95381 41.849...
# 4  POLYGON ((-73.14751 41.36771, -73.14742 41.367...

# %% [markdown]
# ## Merge of ACS Census Data into CT towns map

# %%
## Managing Merge of ACS Census Data into CT towns map

## Pare down ct_towns_gdf for cleaner post-merge outputs:
ct_towns_gdf = ct_towns_gdf[["GEOID20", "NAME20", "geometry"]].copy()
ct_towns_gdf = ct_towns_gdf[
    ~ct_towns_gdf["NAME20"].str.contains(
        "County subdivisions not defined",
        case=False,
        na=False
    )
].copy()
ct_towns_gdf["GEOID20"] = ct_towns_gdf["GEOID20"].astype(str)

## Remove null areas:
DP03_df = DP03_df[
    ~DP03_df["NAME"].str.contains(
        "County subdivisions not defined",
        case=False,
        na=False
    )
].copy()

DP05_df = DP05_df[
    ~DP05_df["NAME"].str.contains(
        "County subdivisions not defined",
        case=False,
        na=False
    )
].copy()

### Function: Merging csv into gdf 
def merge_csv_into_gdf(
    gdf: gpd.GeoDataFrame,
    csv_or_df: Union[str, pd.DataFrame],
    gdf_key: str = "GEOID20",
    csv_geo_col: str = "GEO_ID",
    keep_columns: Iterable[str] = (),
    join_type: str = "left",
) -> gpd.GeoDataFrame:
    """
    Merge ACS CSV/DataFrame into CT towns GeoDataFrame
    using last 10 digits of GEO_ID.
    """

    # Load CSV if needed
    if isinstance(csv_or_df, str):
        df = pd.read_csv(csv_or_df)
    else:
        df = csv_or_df.copy()

    # Extract last 10 digits from ACS GEO_ID
    df["_merge_geoid"] = (
        df[csv_geo_col]
        .astype(str)
        .str[-5:]
    )

    # Ensure matching string type
    gdf["_merge_geoid"] = (
    gdf[gdf_key]
    .astype(str)
    .str[-5:])

    # Keep only merge key + selected ACS columns
    cols_to_use = ["_merge_geoid", *keep_columns]
    df = df[cols_to_use]

    # Merge
    merged = gdf.merge(
    df[["_merge_geoid", *keep_columns]],
    how=join_type,
    on="_merge_geoid")

    # Drop helper column
    merged = merged.drop(columns="_merge_geoid")

    return merged

## Perform merge for census data into CT towns

### Define keep-columns for each data set:
# Columns from DP03
dp03_cols = [
    "DP03_0019E",  # Drove alone
    "DP03_0020E",  # Carpool
    "DP03_0021E",  # Public transit
    "DP03_0022E",  # Walk
    "DP03_0026E",  # Total workers 16+
    "DP03_0025E",  # Mean travel time
    "DP03_0062E",  # Median household income
]

# Columns from DP05
dp05_cols = [
    "DP05_0001E",  # Total population
]

### Two-stage merge:
ct_towns_gdf = merge_csv_into_gdf(
    ct_towns_gdf,
    DP03_df,
    keep_columns=dp03_cols
)

ct_towns_gdf = merge_csv_into_gdf(
    ct_towns_gdf,
    DP05_df,
    keep_columns=dp05_cols
)

# %% [markdown]
# #### Data Cleanup (Removing excess information, false towns)

# %%
##

# %% [markdown]
# ## Calculation of Road Lengths in Towns

# %%
# Calculate Road Lengths in Town

'''
Here, we want to calculate the length of primary and secondary roads
'''

##

# %% [markdown]
# ## Merge Road Data into CT Towns Dataset

# %%
##
