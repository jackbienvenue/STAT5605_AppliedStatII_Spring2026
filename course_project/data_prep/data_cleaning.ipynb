# %% [markdown]
# # Data Cleaning and Preparation for STAT5605 Project

# %%
# Data Upload and Package Install

## Package Install
import pandas as pd
import geopandas as gpd
import numpy as np 
from typing import Iterable, Union
import os
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib_scalebar.scalebar import ScaleBar
import matplotlib.patheffects as pe

## Data Upload
### Roads Dataset
roads_gdf = gpd.read_file('../data/Connecticut_Road/Road.shp')
### CT Towns Dataset
ct_towns_gdf = gpd.read_file('../data/tl_2020_09_all/tl_2020_09_cousub20.shp')
### DP03: Selected Economic Characteristics (from ACS Census 2023)
DP03_df = pd.read_csv(
    '../data/ACS_Selected_Economic_Characteristics_CT_2023/ACSDP5Y2023.DP03-Data.csv',
    skiprows=[1]  
)
### DP05: Demographic and Housing Estimates (from ACS Census 2023)

DP05_df = pd.read_csv(
    '../data/ACS_Demographic_and_Housing_Estimates_CT_2023/ACSDP5Y2023.DP05-Data.csv',
    skiprows=[1]
)
### Crash Data

# %% [markdown]
# ## Merge of ACS Census Data into CT towns map

# %%
## Managing Merge of ACS Census Data into CT towns map

## Pare down ct_towns_gdf for cleaner post-merge outputs:
ct_towns_gdf = ct_towns_gdf[["GEOID20", "NAME20", "geometry"]].copy()
ct_towns_gdf = ct_towns_gdf[
    ~ct_towns_gdf["NAME20"].str.contains(
        "County subdivisions not defined",
        case=False,
        na=False
    )
].copy()
ct_towns_gdf["GEOID20"] = ct_towns_gdf["GEOID20"].astype(str)

## Remove null areas:
DP03_df = DP03_df[
    ~DP03_df["NAME"].str.contains(
        "County subdivisions not defined",
        case=False,
        na=False
    )
].copy()

DP05_df = DP05_df[
    ~DP05_df["NAME"].str.contains(
        "County subdivisions not defined",
        case=False,
        na=False
    )
].copy()

### Function: Merging csv into gdf 
def merge_csv_into_gdf(
    gdf: gpd.GeoDataFrame,
    csv_or_df: Union[str, pd.DataFrame],
    gdf_key: str = "GEOID20",
    csv_geo_col: str = "GEO_ID",
    keep_columns: Iterable[str] = (),
    join_type: str = "left",
) -> gpd.GeoDataFrame:
    """
    Merge ACS CSV/DataFrame into CT towns GeoDataFrame
    using last 10 digits of GEO_ID.
    """

    # Load CSV if needed
    if isinstance(csv_or_df, str):
        df = pd.read_csv(csv_or_df)
    else:
        df = csv_or_df.copy()

    # Extract last 10 digits from ACS GEO_ID
    df["_merge_geoid"] = (
        df[csv_geo_col]
        .astype(str)
        .str[-5:]
    )

    # Ensure matching string type
    gdf["_merge_geoid"] = (
    gdf[gdf_key]
    .astype(str)
    .str[-5:])

    # Keep only merge key + selected ACS columns
    cols_to_use = ["_merge_geoid", *keep_columns]
    df = df[cols_to_use]

    # Merge
    merged = gdf.merge(
    df[["_merge_geoid", *keep_columns]],
    how=join_type,
    on="_merge_geoid")

    # Drop helper column
    merged = merged.drop(columns="_merge_geoid")

    return merged

## Perform merge for census data into CT towns

### Define keep-columns for each data set:
# Columns from DP03
dp03_cols = [
    "DP03_0019E",  # Drove alone
    "DP03_0020E",  # Carpool
    "DP03_0021E",  # Public transit
    "DP03_0022E",  # Walk
    "DP03_0026E",  # Total workers 16+
    "DP03_0025E",  # Mean travel time
    "DP03_0062E",  # Median household income
]

# Columns from DP05
dp05_cols = [
    "DP05_0001E",  # Total population
]

### Two-stage merge:
ct_towns_gdf = merge_csv_into_gdf(
    ct_towns_gdf,
    DP03_df,
    keep_columns=dp03_cols
)

ct_towns_gdf = merge_csv_into_gdf(
    ct_towns_gdf,
    DP05_df,
    keep_columns=dp05_cols
)

# %% [markdown]
# ## Calculation of Road Lengths in Towns

# %%
# Calculate Road Lengths in Town
# ==============================================================================
# ROAD CLASS GROUPINGS - Explicit definitions
# ==============================================================================
#
# GROUP 1: Primary Route Miles (all Class 1 roads)
#   - 'Primary Route, Class 1, Undivided'
#   - 'Primary Route, Class 1, Divided'
#   - 'Primary Route, Class 1, Separated'
#   - 'Primary Route, Class 1, One Way'
#   - 'Cloverleaf, Class 1'          ← interchange ramps on Class 1
#   - 'Traffic Circle, Class 1'      ← roundabouts on Class 1
#   - 'Cloverleaf or Interchange'    ← interchange ramps, class ambiguous → assigned to Class 1
#   - 'Primary Route On Drawbridge, Class 1, Undivided'
#   - 'Tunnel, Class 1'
#   - 'Connector, Class 1'           ← short connectors between Class 1 segments
#
# GROUP 2: Primary Route, Undivided Miles (subset of Group 1)
#   - 'Primary Route, Class 1, Undivided'
#
# GROUP 3: Secondary Route Miles (all Class 2 roads)
#   - 'Secondary Route, Class 2, Undivided'
#   - 'Secondary Route, Class 2, Divided'
#   - 'Secondary Route, Class 2, Separated'
#   - 'Traffic Circle, Class 2'      ← roundabouts on Class 2
#   - 'Secondary Route On Drawbridge, Class 2, Undivided'
#   - 'Road Under Construction, Class 2' ← planned Class 2, included for completeness
#
# GROUP 4: Secondary Route, Undivided Miles (subset of Group 3)
#   - 'Secondary Route, Class 2, Undivided'
#
# GROUP 5: Road or Street Miles (Class 3 and Class 4 local roads)
#   - 'Road or Street, Class 3'
#   - 'Road Or Street, Class 3, Divided'
#   - 'Road Or Street, Class 3, Separated'
#   - 'Road or Street, Class 4'
#   - 'Old Railroad Grade, Road Or Street, Class 4'  ← former rail corridor, now Class 4 road
#   - 'Private Road, Class 4'        ← private but mapped Class 4
#   - 'Cul-De-Sac'                   ← terminal local road segments, no class → local road
#
# EXCLUDED from all groups (non-road or ambiguous features):
#   - 'Trail, Class 5, other than Four Wheel Vehicles'
#   - 'Trail, Class 5, Four Wheel Vehicles'
#   - 'Old Railroad Grade, Trail, Class 5'
#   - 'Non-Standard Section Of Road'
#   - 'Footbridge'
#   - 'Perimeter Of Parking Area'
#   - 'Road Under Construction, Class Unknown'
#   - 'In Service/Rest Area'
#   - 'Ferry Crossing'
#   - 'Toll Plaza'
#   - 'Traffic Circle'               ← no class assigned, excluded
#
# GROUP 6: Total Miles = Groups 1 + 3 + 5 (all included roads)
# ==============================================================================

ROAD_GROUPS = {
    "primary": {
        "Primary Route, Class 1, Undivided",
        "Primary Route, Class 1, Divided",
        "Primary Route, Class 1, Separated",
        "Primary Route, Class 1, One Way",
        "Cloverleaf, Class 1",
        "Traffic Circle, Class 1",
        "Cloverleaf or Interchange",
        "Primary Route On Drawbridge, Class 1, Undivided",
        "Tunnel, Class 1",
        "Connector, Class 1",
    },
    "primary_undivided": {
        "Primary Route, Class 1, Undivided",
    },
    "secondary": {
        "Secondary Route, Class 2, Undivided",
        "Secondary Route, Class 2, Divided",
        "Secondary Route, Class 2, Separated",
        "Traffic Circle, Class 2",
        "Secondary Route On Drawbridge, Class 2, Undivided",
        "Road Under Construction, Class 2",
    },
    "secondary_undivided": {
        "Secondary Route, Class 2, Undivided",
    },
    "road_or_street": {
        "Road or Street, Class 3",
        "Road Or Street, Class 3, Divided",
        "Road Or Street, Class 3, Separated",
        "Road or Street, Class 4",
        "Old Railroad Grade, Road Or Street, Class 4",
        "Private Road, Class 4",
        "Cul-De-Sac",
    },
}

# All road types included in total (union of the three top-level groups)
INCLUDED_ROAD_TYPES = (
    ROAD_GROUPS["primary"]
    | ROAD_GROUPS["secondary"]
    | ROAD_GROUPS["road_or_street"]
)


def calculate_road_miles(
    ct_towns_gdf: gpd.GeoDataFrame,
    roads_gdf: gpd.GeoDataFrame,
) -> gpd.GeoDataFrame:
    """
    Calculate road miles per CT town for each road group defined in ROAD_GROUPS,
    plus a grand total. Clips roads at town boundaries before summing.

    New columns added to ct_towns_gdf:
        road_mi_primary            - all Class 1 roads
        road_mi_primary_undivided  - Class 1, undivided only
        road_mi_secondary          - all Class 2 roads
        road_mi_secondary_undivided- Class 2, undivided only
        road_mi_road_or_street     - Class 3 + Class 4 local roads
        road_mi_total              - sum of primary + secondary + road_or_street
    """

    METERS_PER_MILE = 1609.344
    CT_CRS = 6433  # NAD83(2011) / Connecticut (meters)

    # 1. Align CRS
    if roads_gdf.crs != ct_towns_gdf.crs:
        roads_gdf = roads_gdf.to_crs(ct_towns_gdf.crs)

    # 2. Filter to only included road types
    roads_filtered = roads_gdf[
        roads_gdf["ROAD_CLASS"].isin(INCLUDED_ROAD_TYPES)
    ][["ROAD_CLASS", "geometry"]].copy()

    # 3. Reproject to planar CRS for accurate length
    roads_proj = roads_filtered.to_crs(epsg=CT_CRS)
    towns_proj = ct_towns_gdf[["GEOID20", "geometry"]].to_crs(epsg=CT_CRS)

    # 4. Clip roads at town boundaries
    roads_clipped = gpd.overlay(
        roads_proj,
        towns_proj,
        how="intersection",
        keep_geom_type=True
    )

    # 5. Recalculate length from clipped geometry (in miles)
    roads_clipped["length_mi"] = roads_clipped.geometry.length / METERS_PER_MILE

    # 6. For each group, sum miles per town and attach to result
    result = ct_towns_gdf.copy()

    for group_name, road_type_set in ROAD_GROUPS.items():
        col = f"road_mi_{group_name}"
        group_miles = (
            roads_clipped[roads_clipped["ROAD_CLASS"].isin(road_type_set)]
            .groupby("GEOID20")["length_mi"]
            .sum()
            .reset_index(name=col)
        )
        result = result.merge(group_miles, on="GEOID20", how="left")
        result[col] = result[col].fillna(0.0)

    # 7. Total = primary + secondary + road_or_street (no double-counting subsets)
    result["road_mi_total"] = (
        result["road_mi_primary"]
        + result["road_mi_secondary"]
        + result["road_mi_road_or_street"]
    )

    return result

# %% [markdown]
# ## Merge Road Data into CT Towns Dataset

# %%
# ==============================================================================
# FULL STATE RUN: All CT Towns
# ==============================================================================

# 1. Reload the original full GDFs (not the test subsets)
#    (skip this if ct_towns_gdf and roads_gdf are still in memory from initial load)

# 2. Run road mile calculation on all towns
print("Calculating road miles for all CT towns...")
ct_towns_gdf = calculate_road_miles(ct_towns_gdf, roads_gdf)
print("Done.")

# Quick check on the result
print(f"\nShape: {ct_towns_gdf.shape}")
print("\nRoad mile columns summary:")
road_cols = [c for c in ct_towns_gdf.columns if c.startswith("road_mi_")]
print(ct_towns_gdf[["NAME20"] + road_cols].describe().round(2))

# Spot-check: any towns with zero total miles (worth investigating)
zero_roads = ct_towns_gdf[ct_towns_gdf["road_mi_total"] == 0]["NAME20"].tolist()
if zero_roads:
    print(f"\n⚠ Towns with 0 total road miles (check these): {zero_roads}")
else:
    print("\n✓ All towns have road miles > 0")


# ==============================================================================
# POPULATION DENSITY
# DP05_0001E = total population, ALAND20 would be ideal but we only have geometry
# Instead, calculate area from projected geometry in sq miles
# ==============================================================================

CT_CRS = 6433
SQ_METERS_PER_SQ_MILE = 1609.344 ** 2

ct_towns_gdf["area_sq_mi"] = (
    ct_towns_gdf.to_crs(epsg=CT_CRS).geometry.area / SQ_METERS_PER_SQ_MILE
)

ct_towns_gdf["pop_density_per_sq_mi"] = (
    ct_towns_gdf["DP05_0001E"].astype(float)
    / ct_towns_gdf["area_sq_mi"]
)

print("\nPopulation density check (top 10 most dense):")
print(
    ct_towns_gdf[["NAME20", "DP05_0001E", "area_sq_mi", "pop_density_per_sq_mi"]]
    .sort_values("pop_density_per_sq_mi", ascending=False)
    .head(10)
    .to_string(index=False)
)


# ==============================================================================
# EXPORT MAPS FOR ALL CT TOWNS
# ==============================================================================

output_dir = "../outputs/town_road_maps"
os.makedirs(output_dir, exist_ok=True)

all_towns = ct_towns_gdf["NAME20"].tolist()
print(f"\nGenerating maps for {len(all_towns)} towns...")

for i, town_name in enumerate(all_towns, 1):
    # Clip roads to town bbox first for speed
    town_geom = ct_towns_gdf[ct_towns_gdf["NAME20"] == town_name].to_crs(epsg=CT_CRS)
    bbox = town_geom.total_bounds
    bbox_poly = gpd.GeoSeries.from_wkt(
        [f"POLYGON (({bbox[0]} {bbox[1]}, {bbox[2]} {bbox[1]}, "
         f"{bbox[2]} {bbox[3]}, {bbox[0]} {bbox[3]}, "
         f"{bbox[0]} {bbox[1]}))"],
        crs=CT_CRS
    ).union_all()

    roads_local = roads_gdf[
        roads_gdf.to_crs(epsg=CT_CRS).geometry.intersects(bbox_poly)
    ].copy()

    safe_name = town_name.replace(" ", "_").replace("/", "-")
    save_path = os.path.join(output_dir, f"{safe_name}_roads.png")

    try:
        plot_town_roads(
            town_name=town_name,
            ct_towns_gdf=ct_towns_gdf,
            roads_gdf=roads_local,
            save_path=save_path,
        )
        plt.close("all")  # prevent memory buildup across 169 plots
        print(f"  [{i}/{len(all_towns)}] ✓ {town_name}")
    except Exception as e:
        print(f"  [{i}/{len(all_towns)}] ✗ {town_name}: {e}")


# ==============================================================================
# EXPORT ENHANCED ct_towns_gdf
# ==============================================================================

export_path = "../data/ct_towns_enhanced.gpkg"
ct_towns_gdf.to_file(export_path, driver="GPKG")
print(f"\nExported ct_towns_gdf to: {export_path}")
print(f"Final columns: {ct_towns_gdf.columns.tolist()}")
# Out:
# Calculating road miles for all CT towns...
# Done.
#
# Shape: (169, 17)
#
# Road mile columns summary:
#        road_mi_primary  road_mi_primary_undivided  road_mi_secondary  \
# count           169.00                     169.00             169.00
# mean             21.04                      12.91              29.69
# std              12.21                       7.25              17.26
# min               1.28                       0.00               0.20
# 25%              12.01                       7.47              16.67
# 50%              18.10                      11.62              27.75
# 75%              28.93                      16.95              39.55
# max              60.88                      40.10              73.49
#
#        road_mi_secondary_undivided  road_mi_road_or_street  road_mi_total
# count                       169.00                  169.00         169.00
# mean                         29.59                  101.05         151.79
# ...

# %%
# ==============================================================================
# ROAD GROUP DEFINITIONS FOR PLOTTING
# Color palette chosen for accessibility and clear visual hierarchy
# ==============================================================================

PLOT_GROUPS = [
    {
        "label": "Primary Route (Class 1)",
        "types": ROAD_GROUPS["primary"],
        "color": "#E63946",   # vivid red — highest hierarchy
        "linewidth": 2.2,
        "zorder": 5,
        "linestyle": "-",
    },
    {
        "label": "Secondary Route (Class 2)",
        "types": ROAD_GROUPS["secondary"],
        "color": "#F4A261",   # amber — second tier
        "linewidth": 1.6,
        "zorder": 4,
        "linestyle": "-",
    },
    {
        "label": "Road or Street (Class 3 & 4)",
        "types": ROAD_GROUPS["road_or_street"],
        "color": "#457B9D",   # steel blue — local roads
        "linewidth": 0.8,
        "zorder": 3,
        "linestyle": "-",
    },
]


def plot_town_roads(
    town_name: str,
    ct_towns_gdf: gpd.GeoDataFrame,
    roads_gdf: gpd.GeoDataFrame,
    save_path: str = None,
):
    """
    Plot a single town's road network colored by classification group.

    Parameters
    ----------
    town_name   : Must match NAME20 in ct_towns_gdf exactly
    ct_towns_gdf: Towns GeoDataFrame (any CRS)
    roads_gdf   : Roads GeoDataFrame (any CRS)
    save_path   : If provided, saves figure to this path (e.g. 'Hartford_roads.png')
    """

    PLOT_CRS = 6433  # CT state plane — meters, good for scalebar

    # --- Subset & reproject ---
    town = ct_towns_gdf[ct_towns_gdf["NAME20"] == town_name].to_crs(epsg=PLOT_CRS)
    if town.empty:
        raise ValueError(f"Town '{town_name}' not found in ct_towns_gdf.")

    town_poly = town.union_all()

    # Clip roads to town boundary (reuse overlay logic)
    roads_proj = roads_gdf.to_crs(epsg=PLOT_CRS)
    all_included = (
        ROAD_GROUPS["primary"]
        | ROAD_GROUPS["secondary"]
        | ROAD_GROUPS["road_or_street"]
    )
    roads_filtered = roads_proj[roads_proj["ROAD_CLASS"].isin(all_included)].copy()

    roads_clipped = gpd.overlay(
        roads_filtered[["ROAD_CLASS", "geometry"]],
        town[["geometry"]],
        how="intersection",
        keep_geom_type=True,
    )

    # --- Figure setup ---
    fig, ax = plt.subplots(figsize=(10, 10), facecolor="#F8F4EF")
    ax.set_facecolor("#F8F4EF")

    # Town boundary fill + outline
    town.plot(
        ax=ax,
        color="#E8E0D5",
        edgecolor="#2D2D2D",
        linewidth=1.8,
        zorder=1,
    )

    # --- Plot each road group ---
    legend_patches = []
    for group in PLOT_GROUPS:
        subset = roads_clipped[roads_clipped["ROAD_CLASS"].isin(group["types"])]
        if not subset.empty:
            subset.plot(
                ax=ax,
                color=group["color"],
                linewidth=group["linewidth"],
                linestyle=group["linestyle"],
                zorder=group["zorder"],
            )
        # Always add to legend even if town has zero of that type
        legend_patches.append(
            mpatches.Patch(color=group["color"], label=group["label"])
        )

    # --- Scale bar (matplotlib-scalebar) ---
    scalebar = ScaleBar(
        1,                        # 1 meter per map unit (projected CRS)
        units="m",
        dimension="si-length",
        length_fraction=0.25,
        location="lower left",
        pad=0.5,
        border_pad=0.5,
        sep=4,
        frameon=True,
        color="#2D2D2D",
        box_color="#F8F4EF",
        box_alpha=0.85,
        font_properties={"size": 9},
    )
    ax.add_artist(scalebar)

    # --- Legend ---
    legend = ax.legend(
        handles=legend_patches,
        loc="lower right",
        frameon=True,
        framealpha=0.9,
        edgecolor="#2D2D2D",
        facecolor="#F8F4EF",
        fontsize=9.5,
        title="Road Classification",
        title_fontsize=10,
    )

    # --- Title & labels ---
    ax.set_title(
        f"{town_name} Roads",
        fontsize=18,
        fontweight="bold",
        color="#1A1A1A",
        pad=14,
        fontfamily="serif",
    )

    # Road mile summary subtitle
    town_row = ct_towns_gdf[ct_towns_gdf["NAME20"] == town_name]
    if "road_mi_total" in town_row.columns:
        subtitle = (
            f"Primary: {town_row['road_mi_primary'].values[0]:.1f} mi  |  "
            f"Secondary: {town_row['road_mi_secondary'].values[0]:.1f} mi  |  "
            f"Local: {town_row['road_mi_road_or_street'].values[0]:.1f} mi  |  "
            f"Total: {town_row['road_mi_total'].values[0]:.1f} mi"
        )
        ax.set_xlabel(subtitle, fontsize=8.5, color="#555555", labelpad=8)

    ax.set_axis_off()
    plt.tight_layout()

    if save_path:
        fig.savefig(save_path, dpi=180, bbox_inches="tight")
        print(f"Saved: {save_path}")

    #plt.show()

# %% [markdown]
# # Weather Attribution to Crash Data

# %% [markdown]
# In this section, we want to take our weather data to find the precipitation and wind intensity information for each crash, and add it to our crash data set

# %% [markdown]
# '''
# Sources:
#     HOURLY WEATHER DATA:
#     '/Volumes/JB_Fortress_L3/college_work/EEC/merged_csvs/lat_XX_XXX_lon_(-)XX_XXXXX_time_series_weather1.csv'
#
#         Datetime format: "time
#         1/1/79 0:00"
#
#         Geocode format: "latitude	longitude
#         41.981	-73.62795"
#
#         Fields:
#         "
#         latitude
#         longitude
#         time
#         t2m
#         u10
#         v10
#         tp - NOTE! CUMULATIVE WITHIN DAYS, SUBTRACT PREVIOUS HOUR FROM CURRENT HOUR FOR CURRENT HOUR'S PRECIP INTENSITY! RESETS EVERY DAY SUCH THAT YOU MUST SUBTRACT THE PREVIOUS VALUE FOR MIDNIGHT (EXCEPT THE VERY FIRST MIDNIGHT IN THE DATASET) AND THAT 1AM ENTRIES SHOULD NOT HAVE PREVIOUS VALUES SUBTRACTED!
#         "
#
#     CRASH DATA:
#     '/Users/jackbienvenuejr/Desktop/Desktop - jack-bienvenue/Spring2026Classes/STAT5605/STAT5605_AppliedStatII_Spring2026/course_project/data/clean_crash_data/clean_crash_data.csv'
#
#         What this one has so far for fields:
#         "CrashId
#         Latitude
#         Longitude
#         Date Of Crash
#         Day of the Week
#         Hour of the Day
#         Most Severe Injury
#         Number Of Motor Vehicles
#         Number Of Non-Motorist
#         Route Class
#         First Harmful Event
#         Manner of Crash / Collision Impact
#         Location of First Harmful Event
#         Weather Condition
#         Light Condition	Road Surface Condition
#         Crash Specific Location
#         Type of Intersection"
#
#         Datetime format: "Date Of Crash     Hour of the Day
#         1/3/15      11"
#
#         Geocode format: "Latitude	Longitude
#         41.360649	-71.876469"
#
#
# OUTPUT:
#
#
#
#
#
# '''

# %% [markdown]
# ### Match Weather Data to Crashes

# %%
"""
Weather Attribution to Crash Data
==================================
Drop-in code for the three notebook sections:
  1. Build Set of Points for Grid Cells
  2. Retrieve Weather Data
  3. Output new data

Dependencies: pandas, geopandas, numpy, shapely, pathlib, tqdm (optional)
"""

import os
import glob
import numpy as np
import pandas as pd
import geopandas as gpd
from pathlib import Path
from shapely.geometry import Point, box
from shapely.ops import nearest_points

# ──────────────────────────────────────────────────────────────────────────────
# PATHS 
# ──────────────────────────────────────────────────────────────────────────────
WEATHER_DIR  = "/Volumes/JB_Fortress_L3/college_work/EEC/merged_csvs/"
CRASH_PATH   = (
    "../data/clean_crash_data/pre_weather_crash_data.csv"
)
OUTPUT_PATH  = (
    "/Users/jackbienvenuejr/Desktop/Desktop - jack-bienvenue/Spring2026Classes/"
    "STAT5605/STAT5605_AppliedStatII_Spring2026/course_project/data/"
    "clean_crash_data/crash_data_weather.csv"
)

WEATHER_CRS = "EPSG:4326"   # WGS-84 (lat/lon) — source CRS for both datasets
PROJ_CRS    = "EPSG:6433"   # CT state plane (meters) — used for spatial join


# ==============================================================================
# SECTION 1 — Build Set of Points for Grid Cells
# ==============================================================================

# ── 1a. Extract grid-point locations from the first row of every weather CSV ──

weather_files = sorted(glob.glob(os.path.join(WEATHER_DIR, "*.csv")))
print(f"Found {len(weather_files)} weather CSV files.")

grid_records = []
for fpath in weather_files:
    # Read only the first data row (row index 0 after skiprows=[1] label row)
    # The header row contains: latitude, longitude, time, t2m, u10, v10, tp
    first_row = pd.read_csv(fpath, nrows=1)
    lat = float(first_row["latitude"].iloc[0])
    lon = float(first_row["longitude"].iloc[0])
    grid_records.append({"lat": lat, "lon": lon, "filepath": fpath})

grid_df = pd.DataFrame(grid_records).drop_duplicates(subset=["lat", "lon"])
print(f"Unique grid points: {len(grid_df)}")

# ── 1b. Build Voronoi-style grid cells (bounding-box rectangles) ──
#
# Strategy: each weather station "owns" the rectangle halfway to its neighbours.
# For a regular grid the half-spacing equals half the grid step — we infer the
# step from the sorted unique coordinate values.

lats_sorted = np.sort(grid_df["lat"].unique())
lons_sorted = np.sort(grid_df["lon"].unique())

# Infer typical spacing (median gap between consecutive values)
lat_step = float(np.median(np.diff(lats_sorted))) if len(lats_sorted) > 1 else 0.1
lon_step = float(np.median(np.diff(lons_sorted))) if len(lons_sorted) > 1 else 0.1

half_lat = lat_step / 2.0
half_lon = lon_step / 2.0

print(f"Inferred grid spacing — lat: {lat_step:.4f}°, lon: {lon_step:.4f}°")

def make_cell(lat, lon, half_lat, half_lon):
    """Return a box polygon centred on (lat, lon)."""
    return box(lon - half_lon, lat - half_lat,
               lon + half_lon, lat + half_lat)

grid_df["geometry"] = grid_df.apply(
    lambda r: make_cell(r["lat"], r["lon"], half_lat, half_lon), axis=1
)

grid_gdf = gpd.GeoDataFrame(grid_df, geometry="geometry", crs=WEATHER_CRS)
print("Grid cell GeoDataFrame created.")
# Out:
# Found 220 weather CSV files.
# Unique grid points: 220
# Inferred grid spacing — lat: 0.1000°, lon: 0.1000°
# Grid cell GeoDataFrame created.

# %%
# ── 1c. Intersect crash data with the grid to create crash→weather pairs ──

crash_df = pd.read_csv(CRASH_PATH)
print(f"Crash records loaded: {len(crash_df):,}")

# Drop rows without coordinates
crash_df = crash_df.dropna(subset=["Latitude", "Longitude"]).copy()
crash_df["geometry"] = gpd.points_from_xy(crash_df["Longitude"], crash_df["Latitude"])
crash_gdf = gpd.GeoDataFrame(crash_df, geometry="geometry", crs=WEATHER_CRS)

# Spatial join: each crash gets the grid cell it falls within.
# If a crash falls outside all cells (edge case near state border) we fall back
# to nearest-centroid matching below.
crash_joined = gpd.sjoin(
    crash_gdf,
    grid_gdf[["lat", "lon", "filepath", "geometry"]],
    how="left",
    predicate="within",
)

# Rename joined columns so they don't collide with crash lat/lon
crash_joined = crash_joined.rename(
    columns={"lat": "wx_lat", "lon": "wx_lon", "filepath": "wx_filepath"}
)

# ── Fallback: nearest-centroid match for any unmatched crashes ──
unmatched_mask = crash_joined["wx_filepath"].isna()
n_unmatched = unmatched_mask.sum()
print(f"Crashes needing nearest-centroid fallback: {n_unmatched}")

if n_unmatched > 0:
    # Build centroid GeoDataFrame for nearest-point lookup
    grid_pts = grid_gdf.copy()
    grid_pts["geometry"] = gpd.points_from_xy(grid_pts["lon"], grid_pts["lat"])
    grid_pts_proj = grid_pts.to_crs(PROJ_CRS)

    unmatched = crash_joined[unmatched_mask].copy().to_crs(PROJ_CRS)

    def nearest_weather(crash_geom, grid_pts_proj):
        dists = grid_pts_proj.geometry.distance(crash_geom)
        idx = dists.idxmin()
        row = grid_pts_proj.loc[idx]
        return row["lat"], row["lon"], row["filepath"]

    fallback_results = unmatched.geometry.apply(
        lambda g: nearest_weather(g, grid_pts_proj)
    )
    crash_joined.loc[unmatched_mask, "wx_lat"]      = [r[0] for r in fallback_results]
    crash_joined.loc[unmatched_mask, "wx_lon"]      = [r[1] for r in fallback_results]
    crash_joined.loc[unmatched_mask, "wx_filepath"] = [r[2] for r in fallback_results]

print("All crashes matched to a weather grid point.")


# ==============================================================================
# SECTION 2 — Retrieve Weather Data
# ==============================================================================

# ── 2a. Standardize crash datetime ──

def parse_crash_datetime(date_str, hour_val):
    """
    Converts crash date string ('1/3/15') and integer hour (11)
    to a pandas Timestamp rounded to the hour.
    """
    dt = pd.to_datetime(date_str, format="%m/%d/%y", errors="coerce")
    if pd.isna(dt):
        dt = pd.to_datetime(date_str, infer_datetime_format=True, errors="coerce")
    if pd.isna(dt):
        return pd.NaT
    return dt.replace(hour=int(hour_val), minute=0, second=0)

crash_joined["crash_dt"] = crash_joined.apply(
    lambda r: parse_crash_datetime(r["Date Of Crash"], r["Hour of the Day"]), axis=1
)

n_bad_dt = crash_joined["crash_dt"].isna().sum()
if n_bad_dt:
    print(f"⚠  {n_bad_dt} crash rows could not be parsed to a datetime — they will get NaN weather.")

# ── 2b. Load and process a single weather file → hourly tp, u10, v10 ──

def load_weather_file(fpath: str) -> pd.DataFrame:
    """
    Load one weather CSV, compute HOURLY precipitation from cumulative daily tp.

    ERA5 tp resets at midnight UTC, accumulates each hour.
    - Midnight (00:00): hourly_tp = tp (first entry of the day, no subtraction)
    - 01:00: hourly_tp = tp (first FULL hour after midnight, per source note)
    - 02:00–23:00: hourly_tp = tp[t] - tp[t-1]
    """
    df = pd.read_csv(fpath, skiprows=[1])   # skip the label/unit row if present
    df.columns = df.columns.str.strip()

    # Parse time
    df["time"] = pd.to_datetime(df["time"], infer_datetime_format=True)
    df = df.sort_values("time").reset_index(drop=True)

    # Compute hourly precipitation
    df["hour"] = df["time"].dt.hour
    df["date"] = df["time"].dt.date

    hourly_tp = np.zeros(len(df))
    
    for i, row in df.iterrows():
        if i == 0:
            # Very first row in the entire dataset — no prior value to subtract
            hourly_tp[i] = row["tp"]
        elif row["hour"] == 1:
            # 1am: first hour of new day's accumulation, use raw value directly
            hourly_tp[i] = row["tp"]
        else:
            # All other hours (including midnight/00:00): subtract previous cumulative value
            # Midnight represents the final cumulative total of the *previous* day,
            # so we subtract the 23:00 row's value to isolate that last hour's precip
            hourly_tp[i] = row["tp"] - df.at[i - 1, "tp"]

    df["hourly_tp"] = np.maximum(hourly_tp, 0.0)  # clamp any floating-point negatives

    # Wind speed (m/s) from components
    df["wind_speed"] = np.sqrt(df["u10"] ** 2 + df["v10"] ** 2)
    # Wind direction (degrees, meteorological convention: direction FROM)
    df["wind_dir_deg"] = (np.degrees(np.arctan2(df["u10"], df["v10"])) + 180) % 360

    return df[["time", "t2m", "hourly_tp", "u10", "v10", "wind_speed", "wind_dir_deg"]]


# ── 2c. Retrieve weather for every crash (group by file for efficiency) ──
#
# We group crashes by their matched weather file so we only read each CSV once.

weather_rows = {}   # keyed by (filepath, timestamp) → weather dict

# Gather all unique (filepath, timestamp) pairs we actually need
needed = (
    crash_joined[["wx_filepath", "crash_dt"]]
    .dropna()
    .drop_duplicates()
    .groupby("wx_filepath")["crash_dt"]
    .apply(list)
)

print(f"Unique weather files to read: {len(needed)}")

for fpath, timestamps in needed.items():
    try:
        wx_df = load_weather_file(fpath)
        wx_df = wx_df.set_index("time")

        for ts in timestamps:
            # Round crash timestamp to nearest hour in weather index
            # (ERA5 is on the hour, so exact match expected for same-hour data)
            ts_rounded = ts.floor("H")
            if ts_rounded in wx_df.index:
                row = wx_df.loc[ts_rounded]
                weather_rows[(fpath, ts)] = {
                    "hourly_tp_mm":   row["hourly_tp"],
                    "t2m_K":          row["t2m"],
                    "u10_ms":         row["u10"],
                    "v10_ms":         row["v10"],
                    "wind_speed_ms":  row["wind_speed"],
                    "wind_dir_deg":   row["wind_dir_deg"],
                }
            else:
                # Nearest available hour
                nearest_idx = wx_df.index.get_indexer([ts_rounded], method="nearest")[0]
                if nearest_idx >= 0:
                    row = wx_df.iloc[nearest_idx]
                    weather_rows[(fpath, ts)] = {
                        "hourly_tp_mm":   row["hourly_tp"],
                        "t2m_K":          row["t2m"],
                        "u10_ms":         row["u10"],
                        "v10_ms":         row["v10"],
                        "wind_speed_ms":  row["wind_speed"],
                        "wind_dir_deg":   row["wind_dir_deg"],
                    }
                else:
                    weather_rows[(fpath, ts)] = {k: np.nan for k in
                        ["hourly_tp_mm", "t2m_K","u10_ms", "v10_ms", "wind_speed_ms", "wind_dir_deg"]}
    except Exception as e:
        print(f"  ⚠  Could not process {fpath}: {e}")
        for ts in timestamps:
            weather_rows[(fpath, ts)] = {k: np.nan for k in
                ["hourly_tp_mm", "t2m_K", "u10_ms", "v10_ms", "wind_speed_ms", "wind_dir_deg"]}

print(f"Weather lookups completed: {len(weather_rows):,}")

# ── 2d. Map weather values back to crash rows ──

def get_wx(row):
    key = (row["wx_filepath"], row["crash_dt"])
    return pd.Series(weather_rows.get(key, {
        "hourly_tp_mm":  np.nan,
        "u10_ms":        np.nan,
        "v10_ms":        np.nan,
        "wind_speed_ms": np.nan,
        "wind_dir_deg":  np.nan,
    }))

weather_cols = crash_joined.apply(get_wx, axis=1)
crash_joined = pd.concat([crash_joined.reset_index(drop=True), weather_cols], axis=1)

print("Weather columns appended to crash data.")
print(crash_joined[["CrashId", "crash_dt", "wx_lat", "wx_lon",
                     "hourly_tp_mm", "wind_speed_ms", "wind_dir_deg"]].head())


# ==============================================================================
# SECTION 3 — Output new data
# ==============================================================================

# Drop helper / spatial columns not needed downstream
drop_cols = ["geometry", "index_right", "wx_filepath"]
crash_out = crash_joined.drop(columns=[c for c in drop_cols if c in crash_joined.columns])

# Reorder so weather columns appear right after the original crash fields
original_cols = [c for c in crash_df.columns if c in crash_out.columns and c != "geometry"]
new_cols      = ["crash_dt", "wx_lat", "wx_lon",
                 "hourly_tp_mm", "u10_ms", "v10_ms", "wind_speed_ms", "wind_dir_deg"]
remaining     = [c for c in crash_out.columns if c not in original_cols + new_cols]

crash_out = crash_out[original_cols + new_cols + remaining]

os.makedirs(os.path.dirname(OUTPUT_PATH), exist_ok=True)
crash_out.to_csv(OUTPUT_PATH, index=False)
print(f"\n✓ Saved weather-attributed crash data to:\n  {OUTPUT_PATH}")
print(f"  Rows: {len(crash_out):,}  |  Columns: {len(crash_out.columns)}")

# Quick summary of new weather columns
print("\nWeather column summary:")
print(crash_out[["hourly_tp_mm", "wind_speed_ms", "wind_dir_deg"]].describe().round(4))
# Out:
# Crash records loaded: 282,360
# Crashes needing nearest-centroid fallback: 126
# All crashes matched to a weather grid point.
# /var/folders/lt/90cmmvp91vn9qgdwpxyyb6l40000gn/T/ipykernel_78531/3617885213.py:68: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dt = pd.to_datetime(date_str, infer_datetime_format=True, errors="coerce")
# Unique weather files to read: 158
# /var/folders/lt/90cmmvp91vn9qgdwpxyyb6l40000gn/T/ipykernel_78531/3617885213.py:96: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
# ...

# %%
# Out:
# === CRASH INFO ===
#   CrashId:      690
#   Crash lat/lon: 41.36858, -72.7193
#   crash_dt:     2015-01-03 16:00:00
#
# === MATCHED WEATHER GRID POINT ===
#   wx_lat:       41.381
#   wx_lon:       -72.72747
#   wx_filepath:  /Volumes/JB_Fortress_L3/college_work/EEC/merged_csvs/lat_41_381_lon_-72_72747_time_series_weather.csv
#
# === FILE HEADER CHECK ===
#   File's latitude:  41.381
#   File's longitude: -72.72747
#   Match: lat=True, lon=True
# /var/folders/lt/90cmmvp91vn9qgdwpxyyb6l40000gn/T/ipykernel_78531/673979447.py:29: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   test_full["time"] = pd.to_datetime(test_full["time"], infer_datetime_format=True)
# ...

# %%
# ==============================================================================
# PRECIPITATION INTENSITY BREAKDOWN
# ==============================================================================

output_df = pd.read_csv(OUTPUT_PATH)

tp = output_df["hourly_tp_mm"]
n_total = len(tp)

# Define bins
dry       = tp < 0.0001
light     = (tp >= 0.0001)  & (tp < .0025)
moderate  = (tp >= .0025)  & (tp < .0076)
heavy     = (tp >= .0076)  & (tp < .025)
violent   = tp >= .025
missing   = tp.isna()

categories = {
    "Dry / Trace (< 0.1 mm/hr)":       dry,
    "Light rain (0.1 – 2.5 mm/hr)":    light,
    "Moderate rain (2.5 – 7.6 mm/hr)": moderate,
    "Heavy rain (7.6 – 25 mm/hr)":     heavy,
    "Violent rain (≥ 25 mm/hr)":       violent,
    "Missing / unmatched":             missing,
}

print(f"{'Category':<35} {'Count':>8}  {'%':>7}")
print("-" * 55)
for label, mask in categories.items():
    count = mask.sum()
    pct   = 100 * count / n_total
    print(f"{label:<35} {count:>8,}  {pct:>6.2f}%")
print("-" * 55)
print(f"{'TOTAL':<35} {n_total:>8,}  100.00%")

# Non-missing base for rain-only proportions
n_valid = (~missing).sum()
print(f"\nAmong non-missing observations (n={n_valid:,}):")
for label, mask in list(categories.items())[:-1]:   # skip missing
    count = mask.sum()
    pct   = 100 * count / n_valid
    print(f"  {label:<33} {pct:.2f}%")
# Out:
# Category                               Count        %
# -------------------------------------------------------
# Dry / Trace (< 0.1 mm/hr)            240,689   85.24%
# Light rain (0.1 – 2.5 mm/hr)          34,245   12.13%
# Moderate rain (2.5 – 7.6 mm/hr)        2,882    1.02%
# Heavy rain (7.6 – 25 mm/hr)              119    0.04%
# Violent rain (≥ 25 mm/hr)                  0    0.00%
# Missing / unmatched                    4,425    1.57%
# -------------------------------------------------------
# TOTAL                                282,360  100.00%
#
# Among non-missing observations (n=277,935):
#   Dry / Trace (< 0.1 mm/hr)         86.60%
#   Light rain (0.1 – 2.5 mm/hr)      12.32%
#   Moderate rain (2.5 – 7.6 mm/hr)   1.04%
#   Heavy rain (7.6 – 25 mm/hr)       0.04%
#   Violent rain (≥ 25 mm/hr)         0.00%

# %% [markdown]
# # Add Features for Number of Vehicles, Passengers Involved, Age and Type of Vehicles
